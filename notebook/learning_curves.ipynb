# %%
#we need sys.path.append  when  train.py is in a different folder
"""import sys
import os
PROJECT_ROOT = os.path.abspath("..")
sys.path.append(PROJECT_ROOT) """
# Out:
# 'import sys\nimport os\nPROJECT_ROOT = os.path.abspath("..")\nsys.path.append(PROJECT_ROOT) '

# %%
# !pip install numpy
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 # 1. Plot the rewards
#       2 plt.figure(figsize=(10,5))
# ----> 3 plt.plot(rewards_history)
#       4 plt.title("Agent Learning Progress")
#       5 plt.xlabel("Episode")
#
# NameError: name 'rewards_history' is not defined

# %%
# check the Q-Table
print("Final Q-Table(Top-Left Corner)")
print(agent.q_table[:5])
#Q-Table show the agent’s knowledge about the best actions to take in each state.
# Out:
# Final Q-Table(Top-Left Corner)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # check the Q-Table
#       2 print("Final Q-Table(Top-Left Corner)")
# ----> 3 print(agent.q_table[:5])
#       4 #Q-Table show the agent’s knowledge about the best actions to take in each state.
#
# NameError: name 'agent' is not defined
