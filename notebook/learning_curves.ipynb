# %%
#we need sys.path.append  when  train.py is in a different folder
'''import sys
import os
PROJECT_ROOT = os.path.abspath("..")
sys.path.append(PROJECT_ROOT) '''

# %%
# !pip install numpy pandas
# !pip install matplotlib
# Out:
# ...
#   Using cached pandas-3.0.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-3.0.2-cp312-cp312-win_amd64.whl (9.7 MB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
from train import agent, rewards_history

# %%
# 1. Plot the rewards
plt.figure(figsize=(10,5))
plt.plot(rewards_history)
plt.title("Agent Learning Progress")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.grid(True,alpha=0.3)
plt.show()

# %%
# check the Q-Table
print("Final Q-Table(Top-Left Corner)")
print(agent.q_table[:5])
# Q-Table shows the agent's knowledge about the best actions to take in each state.
# Out:
# Final Q-Table(Top-Left Corner)
# [[ 2.8539719   3.3363388   2.86879449  4.348907  ]
#  [ 4.26254472  0.30297987  2.84573348  5.94323   ]
#  [ 5.83925699  1.90862565  4.30201498  7.7147    ]
#  [ 7.67334663  9.64936913  5.85802494  9.683     ]
#  [ 9.66514053 11.87        7.67155231  9.66340136]]
